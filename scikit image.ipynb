# %% [markdown]
# ## Image processing using scikit image

# %% [markdown]
# basic image transformation tasks - rescale and resize

# %%
from matplotlib import pyplot as plt

from skimage import io, color
from skimage.transform import rescale, resize, downscale_local_mean

# %%
img = io.imread("saved_using_skimage.jpg", as_gray = True)

#Rescale, resize image by a given factor.
# While rescaling image, gaussian smoothing can be performed to avoid anti aliasing artifacts.
img_rescaled =  rescale(img, 1.0/4.0, anti_aliasing=False)

# %%
io.imshow(img)

# %%
img.shape
# Out:
# (183, 275)

# %%
io.imshow(img_rescaled)

# %%
img_rescaled.shape
# Out:
# (46, 69)

# %%
#Resize, resize image to given dimensions (shape)

img_resized = resize(img, (200,200), anti_aliasing=True)
io.imshow(img_resized)

# %%
img_resized.shape
# Out:
# (200, 200)

# %%
#Downscale, downsample using local mean of elements of each block defined by user

img_downscaled = downscale_local_mean(img, (4,3))
io.imshow(img_downscaled)

# %%
img_downscaled.shape
# Out:
# (46, 92)

# %%
# a few skimage functions

from skimage.filters import gaussian, sobel

img = io.imread("saved_using_skimage.jpg")
plt.imshow(img)

# %% [markdown]
# Gaussian - Multi-dimensional Gaussian filter
#
# - image : array-like
#     Input image (grayscale or color) to filter.
# - sigma : scalar or sequence of scalars, optional
#         Standard deviation for Gaussian kernel. The standard
#         deviations of the Gaussian filter are given for each axis as a
#         sequence, or as a single number, in which case it is equal for
#         all axes.
# - mode : {'reflect', 'constant', 'nearest', 'mirror', 'wrap'}, optional
#         The ``mode`` parameter determines how the array borders are
#         handled, where ``cval`` is the value when mode is equal to
#         'constant'. Default is 'nearest'.
# - cval : scalar, optional
#         Value to fill past edges of input if ``mode`` is 'constant'. Default
#         is 0.0
#
# Returns - filtered_image : ndarray
#         the filtered array

# %%
gaussian_using_skimage = gaussian(img, sigma=1, mode='constant', cval=0.0)
plt.imshow(gaussian_using_skimage)
# Out:
# <ipython-input-21-43023122cc87>:1: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   gaussian_using_skimage = gaussian(img, sigma=1, mode='constant', cval=0.0)

# %% [markdown]
# Sobel - Find the edge magnitude using the Sobel transform.
#
# Returns - output : 2-D array
#         The Sobel edge map.

# %%
img_gray = io.imread("saved_using_skimage.jpg", as_gray=True)
sobel_img = sobel(img_gray)    #Works only on 2D (gray) images
plt.imshow(sobel_img, cmap="gray")
